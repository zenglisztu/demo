# %%
import pandas as pd
import easyocr
import os

# %%
#获取所有图片路径
dir_path = r'./media'
files = os.listdir(dir_path)
#实例化一个ocr
ocr = easyocr.Reader(['ch_sim','en'], gpu=True)
#
text = ocr.readtext(f'{dir_path}/{files[0]}')
words = []
#for file in files:
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
pd.DataFrame(text)[[1]]
# Out:
#                                1
# 0                    四级词汇闪过_已学单词
# 1                     invariably
# 2                  adv. 不娈地;  总是
# 3                     persistent
# 4           adj. 执着的;  坚持的;  持续的
# 5                     apparently
# 6             adv. 据说;  似乎;  显然地
# 7                    transaction
# 8                              几
# 9                         交易; 业务
# 10                      tangible
# 11   adj. 可触摸的;  实际的;  有形的;  确凿的
# 12                   deteriorate
# 13                            V:
# 14                   恶化; 娈坏;  退化
# 15                          amid
# 16                     prep. 在其中
# 17                        tumour
# 18                     n。肿瘤;  肿块
# 19                       persist
# 20                            V。
# 21                        坚持; 持续
# 22                     exclusive
# 23          adj. 独有的;  高级的;  排外的
# 24                       contend
# 25                             V
# 26              声称; 主张;  竞争;  争辩
# ...

# %%
def m(z1, z2):
    return (2 * 10) /(z1 + z2)

# %%
m(30, 14)
# Out:
# 0.45454545454545453

# %%
m(16, 28)
# Out:
# 0.45454545454545453

# %%
m(35, 9)
# Out:
# 0.45454545454545453

# %%
m(8, 32)
# Out:
# 0.5
